# %% [markdown]
# ## Autoevaluación 8

# %% [markdown]
# #### Pregunta 1

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
#  campo escalar ✅
#
# ¿Por qué?
#
# El lagrangiano es una función que asocia a cada combinación de variables de decisión x y multiplicadores de Lagrange \lambda, un valor escalar.
#
# Se escribe típicamente así:
#
# \mathcal{L}(x, \lambda) = f(x) + \lambda^T g(x)
#
# Donde:
# 	•	f(x) es la función objetivo (escalar),
# 	•	g(x) representa las restricciones,
# 	•	\lambda son los multiplicadores.
#
# 🧠 Como devuelve un escalar y depende de múltiples variables (un vector), se considera un campo escalar: una función que asigna un escalar a cada punto de un espacio vectorial.

# %% [markdown]
# #### Pregunta 2

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
# Variables del problema
num_variables = 9
num_restricciones = 5

# Total de variables en el lagrangiano
total_lagrangiano = num_variables + num_restricciones
total_lagrangiano
# Out:
# 14

# %% [markdown]
# #### Pregunta 3

# %% [markdown]
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# La afirmación es falsa.
#
# No todos los puntos estacionarios son óptimos del problema. Un punto estacionario es simplemente un candidato a óptimo (puede ser un mínimo local, máximo local o punto de silla). Para determinar si es un óptimo, se deben analizar condiciones de segundo orden u otras propiedades del problema.

# %% [markdown]
# #### Pregunta 4

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# La respuesta correcta es: c. sí bajo dualidad fuerte.
#
# Resolver el problema dual equivale a resolver el problema primal si se cumple la condición de dualidad fuerte, es decir, si los valores óptimos del problema primal y del dual coinciden. Esto suele ocurrir, por ejemplo, cuando el primal es convexo y cumple ciertas condiciones regulares (como las condiciones de Slater).

# %% [markdown]
# #### Pregunta 5

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# En un problema de optimización, el problema dual tiene tantas variables como restricciones tiene el problema primal.
#
# Entonces, si el problema primal tiene 9 variables y 5 restricciones, el dual tiene 5 variables.
#
# ✅ Respuesta correcta: a. 5.

# %% [markdown]
# #### Pregunta 6

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# Falso ❌
#
# En optimización convexa, todo mínimo local es también un mínimo global si se cumplen ciertas condiciones (por ejemplo, si la función objetivo es convexa y el conjunto factible también lo es). Sin embargo:
#
# No todos los puntos estacionarios son necesariamente óptimos.
#
# Un punto estacionario es aquel donde el gradiente de la función objetivo se anula o se vuelve ortogonal al espacio factible. Pero:
# - Puede tratarse de un punto de silla (ni mínimo ni máximo),
# - O un punto factible que no satisface las condiciones de Karush-Kuhn-Tucker (KKT) si hay restricciones activas.
#
# ✅ Entonces:
# - Si es problema convexo y se cumplen las condiciones KKT, sí el punto estacionario es mínimo global.
# - Pero no cualquier punto estacionario garantiza esto per se, sin más información.

# %% [markdown]
# #### Pregunta 7

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
#  ✅ Verdadero
#
# En un problema de programación lineal:
# 	•	La función objetivo es lineal.
# 	•	El conjunto factible es convexo (intersección de restricciones lineales).
# 	•	No hay mínimos locales que no sean también globales.
#
# Por lo tanto, todo punto estacionario que sea factible (cumple las restricciones) es un mínimo global.

# %% [markdown]
# #### Pregunta 8

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Verdadero
#
# En un problema de programación cuadrática (QP) convexo, es decir, cuando la matriz cuadrática en la función objetivo es definida positiva semidefinida (PSD) y las restricciones son lineales, todos los puntos estacionarios son mínimos globales.
#
# Y eso es lo que se asume por defecto cuando hablamos de “programación cuadrática”, a menos que se diga explícitamente lo contrario.

# %% [markdown]
# #### Pregunta 9

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# La afirmación es falsa.
#
# En un problema de programación cuadrática (QP, Quadratic Programming), solo la función objetivo es cuadrática, mientras que las restricciones son lineales.
#
# Formalmente, un QP se expresa como:
# $$
# \text{minimizar} \quad \frac{1}{2}x^T Q x + c^T x \\
# \text{sujeto a} \quad A x \leq b
# $$
