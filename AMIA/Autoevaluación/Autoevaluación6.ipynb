# %% [markdown]
# ## Autoevaluación 6

# %% [markdown]
# ### BackPropagation

# %% [markdown]
# #### Pregunta 1

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ✅ **Verdadero**
#
# En optimización clásica (o “común”), se suele asumir que se conoce toda la información del sistema: parámetros, restricciones, funciones objetivo… todo es determinista y confiable.
#
# En cambio, en Machine Learning, trabajamos con:
# - Datos parciales, ruidosos o inciertos
# - Modelos que aprenden a partir de ejemplos, no de reglas exactas
# - Funciones objetivo que reflejan errores de predicción, no certezas

# %% [markdown]
# #### Pregunta 2

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ✅ **Verdadero**
#
# En aprendizaje supervisado, se suelen distinguir dos funciones:
#
# - L - (la función de pérdida): Evalúa qué tan bien se comporta el modelo en un punto específico.
#     - Los parámetros del modelo están fijos
#     - Se calcula en función de los datos de entrada y salida
# - J (la función de costo o función objetivo): Se usa para optimizar el modelo, evaluando el error global.
#     - Los datos se consideran fijos
#     - Se busca ajustar los parámetros para minimizar esta función

# %% [markdown]
# #### Pregunta 3

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ❌ **Falso**
#
# En Machine Learning, la función de costo J utilizada en train y test debe ser la misma o coherente, porque:
# - La función de costo es la base sobre la cual se entrena el modelo
# - Usar una función distinta en test impediría comparar el rendimiento real del modelo respecto al criterio de optimización
# - Por ejemplo, si entrenás minimizando el error cuadrático medio, pero evaluás con precisión, estarías optimizando una cosa y evaluando otra, lo que lleva a resultados inconsistentes o engañosos

# %% [markdown]
# #### Pregunta 4

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ❌ **Falso**
#
# El principal beneficio de conocer una solución óptima analítica (es decir, exacta y expresada en forma cerrada) no es necesariamente que sea más rápida, sino que:
# - Es exacta, sin necesidad de métodos iterativos ni tolerancias numéricas.
# - Sirve como referencia teórica para validar algoritmos numéricos.
# - Ayuda a entender mejor el comportamiento del modelo.
#
# ⚠️ Por qué “más rápido” no siempre aplica:
# - Calcular la solución analítica puede requerir operaciones costosas (como invertir matrices grandes).
# - En problemas complejos o con regularización, el enfoque numérico (como gradiente descendente) puede ser más eficiente.

# %% [markdown]
# #### Pregunta 5

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ❌ **Falso**
#
# Los métodos de optimización de primer orden (como gradiente descendente):
# - Solo usan la derivada (gradiente) de la función
# - Son más baratos computacionalmente por iteración
# - Pero suelen requerir más iteraciones para converger
# - Son menos precisos en general que los métodos de segundo orden
#
# En cambio, los métodos de segundo orden (como Newton o quasi-Newton):
# - Usan la derivada y la segunda derivada (Hessiano) o una aproximación
# - Son más costosos por iteración (por el cálculo o inversión del Hessiano)
# - Pero convergen más rápido y con mayor precisión

# %% [markdown]
# #### Pregunta 6

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ✅ **minimo local**
#
#
# El algoritmo de Gradient Descent (GD) busca descender en la dirección del gradiente para minimizar una función.
# - En funciones no convexas, puede quedar atrapado en un mínimo local.
# - Solo en funciones convexas se garantiza que cualquier mínimo local sea también el mínimo global.
# - Si la función es mal condicionada o no diferenciable en puntos clave, puede no converger, pero eso depende de la implementación y del learning rate.

# %% [markdown]
# #### Pregunta 7

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ✅ **Verdadero**
#
# En Gradient Descent (GD), es posible aplicar estrategias de scheduling del learning rate (como reducirlo con el tiempo), sin importar si se usa:
# - GD clásico
# - GD con Momentum
# - Adam
# - RMSprop, etc.
#
# Estos métodos son variantes de GD que mejoran su desempeño, y todas aceptan scheduling del learning rate.

# %% [markdown]
# #### Pregunta 8

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# **✅ 1 < m <= n**
#
#
# En Machine Learning, la estrategia de batching más común es el mini-batch gradient descent, que usa:
# - Un tamaño de batch intermedio: ni 1 (como SGD puro), ni n (como batch gradient descent completo)
# - Se elige m tal que:
# 1 < m <= n → es decir, mucho menor que el tamaño total del dataset, pero mayor a 1
#
# 📊 ¿Por qué?
# - Balancea eficiencia computacional y calidad del gradiente
# - Usa menos memoria que el batch completo
# - Es menos ruidoso que el batch de tamaño 1 (SGD puro)
